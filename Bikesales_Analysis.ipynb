# %%
#import libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Importing File

# %%
#import file
df = pd.read_excel('Group Assessment 1.xlsx')

# %%
df
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %% [markdown]
# ## Data Cleaning

# %%
#Check duplicates
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
#drop duplicates
df.drop_duplicates()
# Out:
#         ID Marital Status Gender  Income  Children        Education  \
# 0    12496              M      F   40000         1        Bachelors
# 1    24107              M      M   30000         3  Partial College
# 2    14177              M      M   80000         5  Partial College
# 3    24381              S      M   70000         0        Bachelors
# 4    25597              S      M   30000         0        Bachelors
# ..     ...            ...    ...     ...       ...              ...
# 995  23731              M      M   60000         2      High School
# 996  28672              S      M   70000         4  Graduate Degree
# 997  11809              M      M   60000         2        Bachelors
# 998  19664              S      M  100000         3        Bachelors
# 999  12121              S      M   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# 0    Skilled Manual        Yes     0        0-1 Miles         Europe   42
# ...

# %%
df["Marital Status"].replace(["M","S"], ["Married","Single"], inplace=True)
df["Gender"].replace(["F","M"],["Female","Male"], inplace=True)

# %%
df
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %% [markdown]
# df["Gender"] = df["Gender"].replace(["F", "M"], ["Female", "Male"])

# %%
#no of rows and columns
df.shape
# Out:
# (1000, 13)

# %%
#statistical description
df.describe()
# Out:
#                  ID         Income     Children         Cars          Age
# count   1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean   19965.992000   56360.000000     1.898000     1.442000    44.163000
# std     5347.333948   31085.635215     1.628572     1.125123    11.364488
# min    11000.000000   10000.000000     0.000000     0.000000    25.000000
# 25%    15290.750000   30000.000000     0.000000     1.000000    35.000000
# 50%    19744.000000   60000.000000     2.000000     1.000000    43.000000
# 75%    24470.750000   70000.000000     3.000000     2.000000    52.000000
# max    29447.000000  170000.000000     5.000000     4.000000    89.000000

# %%
#data types
df.dtypes
# Out:
# ID                   int64
# Marital Status      object
# Gender              object
# Income               int64
# Children             int64
# Education           object
# Occupation          object
# Home Owner          object
# Cars                 int64
# Commute Distance    object
# Region              object
# Age                  int64
# Purchased Bike      object
# dtype: object

# %%
#no of rows
df.shape[0]
# Out:
# 1000

# %%
#no of columns
df.shape[1]
# Out:
# 13

# %%
#defining function for grouping age
def age_grouping(age):
    if age<=30:
        return "Adolescent"
    elif age<=54:
        return "Middle Age"
    else:
        return "Old"

# %%
df["Age Bracket"] = df["Age"].apply(age_grouping)

# %%
df
# Out:
#         ID Marital Status  Gender  Income  Children        Education  \
# 0    12496        Married  Female   40000         1        Bachelors
# 1    24107        Married    Male   30000         3  Partial College
# 2    14177        Married    Male   80000         5  Partial College
# 3    24381         Single    Male   70000         0        Bachelors
# 4    25597         Single    Male   30000         0        Bachelors
# ..     ...            ...     ...     ...       ...              ...
# 995  23731        Married    Male   60000         2      High School
# 996  28672         Single    Male   70000         4  Graduate Degree
# 997  11809        Married    Male   60000         2        Bachelors
# 998  19664         Single    Male  100000         3        Bachelors
# 999  12121         Single    Male   60000         3      High School
#
#          Occupation Home Owner  Cars Commute Distance         Region  Age  \
# ...

# %% [markdown]
# df.groupby(["Gender", "Purchased Bike"])["Income"].mean()

# %%
pivot1 = np.round(df.pivot_table(index="Gender", columns="Purchased Bike", values="Income", aggfunc="mean"),0)
pivot1
# Out:
# Purchased Bike       No      Yes
# Gender
# Female          53440.0  55774.0
# Male            56208.0  60124.0

# %%
pivot1.plot(kind = 'bar', figsize=(7,4))
plt.title('Pivot Chart 1')
plt.xlabel('Gender')
plt.ylabel('Average Income')
# Out:
# Text(0, 0.5, 'Average Income')

# %%
pivot2 = df.groupby(["Commute Distance", "Purchased Bike"])["Purchased Bike"].aggregate('count').unstack()
pivot2
# Out:
# Purchased Bike     No  Yes
# Commute Distance
# 0-1 Miles         166  200
# 1-2 Miles          92   77
# 10+ Miles          78   33
# 2-5 Miles          67   95
# 5-10 Miles        116   76

# %%
#pivot2 = pd.DataFrame(df.groupby(["Commute Distance", "Purchased Bike"])["Purchased Bike"].count())

# %%
pivot2.plot(kind = 'line', figsize=(7,4))
plt.title('Pivot Chart2')
plt.xlabel('Commute Distance')
plt.ylabel('Purchased Bike')
plt.show()

# %%
pivot3 = pd.DataFrame(df.groupby(["Age Bracket", "Purchased Bike"])["Purchased Bike"].aggregate('count').unstack())
pivot3
# Out:
# Purchased Bike   No  Yes
# Age Bracket
# Adolescent       71   39
# Middle Age      318  383
# Old             130   59

# %%
pivot3.plot(kind = 'line', figsize=(7,4))
plt.title('Pivot Chart3')
plt.xlabel('Age Bracket')
plt.ylabel('Purchased Bike')
plt.show()
